# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./US_violent_crime.csv', error_bad_lines=False)
df
# Out:
# /home/linuxbrew/.linuxbrew/opt/python@3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# ...

# %% [markdown]
# # Top 5 cities murders

# %%
df.head(5)
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %% [markdown]
# # a graph showing not all Assaults end up with murders some Assaults happen for the sake of it.

# %%
compare = df[['Murder','Assault']].sort_values('Murder',ascending=False)
relplotting = sns.lmplot(x="Murder",y="Assault",data=compare.head(40))
compare.head()
relplotting

# %% [markdown]
# # the average Assault number in the US

# %%
df['Assault'].mean()
# Out:
# 170.76

# %% [markdown]
# # sammary
# - murder rates are getting super high.
# - Assault rates are getting super higher.
